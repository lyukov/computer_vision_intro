# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !mkdir data

# %%
# !cp -r "drive/My Drive/BirdsSegm/public_tests/00_test_val_input/train" data

# %%
import os

root_dir   = '/content/drive/My Drive/BirdsSegm/'
train_dir  = os.path.join('data', 'train')
images_dir = os.path.join(train_dir, 'images')
masks_path = os.path.join(train_dir, 'gt')
model_dir  = os.path.join(root_dir, 'models')

# %%
from skimage.io import imread
from skimage.transform import resize
from skimage import img_as_float
import numpy as np
import os
import skimage.io as io
import skimage.transform as trans
import numpy as np
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, Dropout, Input, concatenate, UpSampling2D
from keras.optimizers import Adam
from keras.initializers import he_normal
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import VGG16
from keras.models import load_model

# %%
def unet(input_size = (256,256,3), seed=42, pretrained_weights = None, base = 32, actv='relu'):
    inputs = Input(input_size)
    kern_init = kernel_initializer=he_normal(seed=seed)
    conv1 = Conv2D(base,    3, activation=actv, padding='same', )(inputs)
    conv1 = Conv2D(base,    3, activation=actv, padding='same', kernel_initializer=kern_init)(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    
    conv2 = Conv2D(base*2,  3, activation=actv, padding='same', kernel_initializer=kern_init)(pool1)
    conv2 = Conv2D(base*2,  3, activation=actv, padding='same', kernel_initializer=kern_init)(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    
    conv3 = Conv2D(base*4,  3, activation=actv, padding='same', kernel_initializer=kern_init)(pool2)
    conv3 = Conv2D(base*4,  3, activation=actv, padding='same', kernel_initializer=kern_init)(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    
    conv4 = Conv2D(base*8,  3, activation=actv, padding='same', kernel_initializer=kern_init)(pool3)
    conv4 = Conv2D(base*8,  3, activation=actv, padding='same', kernel_initializer=kern_init)(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(base*16, 3, activation=actv, padding='same', kernel_initializer=kern_init)(pool4)
    conv5 = Conv2D(base*16, 3, activation=actv, padding='same', kernel_initializer=kern_init)(conv5)
    drop5 = Dropout(0.5)(conv5)

    up6   = Conv2D(base*8,  2, activation=actv, padding='same', kernel_initializer=kern_init)(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(base*8,  3, activation=actv, padding='same', kernel_initializer=kern_init)(merge6)
    conv6 = Conv2D(base*8,  3, activation=actv, padding='same', kernel_initializer=kern_init)(conv6)

    up7   = Conv2D(base*4,  2, activation=actv, padding='same', kernel_initializer=kern_init)(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(base*4,  3, activation=actv, padding='same', kernel_initializer=kern_init)(merge7)
    conv7 = Conv2D(base*4,  3, activation=actv, padding='same', kernel_initializer=kern_init)(conv7)

    up8   = Conv2D(base*2,  2, activation=actv, padding='same', kernel_initializer=kern_init)(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(base*2,  3, activation=actv, padding='same', kernel_initializer=kern_init)(merge8)
    conv8 = Conv2D(base*2,  3, activation=actv, padding='same', kernel_initializer=kern_init)(conv8)

    up9   = Conv2D(base,    2, activation=actv, padding='same', kernel_initializer=kern_init)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(base,    3, activation=actv, padding='same', kernel_initializer=kern_init)(merge9)
    conv9 = Conv2D(base,    3, activation=actv, padding='same', kernel_initializer=kern_init)(conv9)
    conv9 = Conv2D(2,       3, activation=actv, padding='same', kernel_initializer=kern_init)(conv9)
    conv10 = Conv2D(1,      1, activation = 'sigmoid')(conv9)

    model = Model(input = inputs, output = conv10)

    model.compile(optimizer = Adam(lr = 1e-4), loss = 'binary_crossentropy', metrics = ['accuracy', iou])
    
    if(pretrained_weights):
        model.load_weights(pretrained_weights)

    return model


def unet_vgg16(input_size = (256,256,3), seed=42, pretrained_weights = None, actv='relu'):
    inputs = Input(input_size)
    kern_init = kernel_initializer=he_normal(seed=seed)
    conv1 = Conv2D(64,  3, activation=actv, padding='same', )(inputs)
    conv1 = Conv2D(64,  3, activation=actv, padding='same', kernel_initializer=kern_init)(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    
    conv2 = Conv2D(128, 3, activation=actv, padding='same', kernel_initializer=kern_init)(pool1)
    conv2 = Conv2D(128, 3, activation=actv, padding='same', kernel_initializer=kern_init)(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    
    conv3 = Conv2D(256, 3, activation=actv, padding='same', kernel_initializer=kern_init)(pool2)
    conv3 = Conv2D(256, 3, activation=actv, padding='same', kernel_initializer=kern_init)(conv3)
    conv3 = Conv2D(256, 3, activation=actv, padding='same', kernel_initializer=kern_init)(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    
    conv4 = Conv2D(512, 3, activation=actv, padding='same', kernel_initializer=kern_init)(pool3)
    conv4 = Conv2D(512, 3, activation=actv, padding='same', kernel_initializer=kern_init)(conv4)
    conv4 = Conv2D(512, 3, activation=actv, padding='same', kernel_initializer=kern_init)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, 3, activation=actv, padding='same', kernel_initializer=kern_init)(pool4)
    conv5 = Conv2D(512, 3, activation=actv, padding='same', kernel_initializer=kern_init)(conv5)
    conv5 = Conv2D(512, 3, activation=actv, padding='same', kernel_initializer=kern_init)(conv5)
    drop5 = Dropout(0.5)(conv5)

    up6   = Conv2D(512, 2, activation=actv, padding='same', kernel_initializer=kern_init)(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([conv4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation=actv, padding='same', kernel_initializer=kern_init)(merge6)
    conv6 = Conv2D(512, 3, activation=actv, padding='same', kernel_initializer=kern_init)(conv6)

    up7   = Conv2D(256, 2, activation=actv, padding='same', kernel_initializer=kern_init)(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation=actv, padding='same', kernel_initializer=kern_init)(merge7)
    conv7 = Conv2D(256, 3, activation=actv, padding='same', kernel_initializer=kern_init)(conv7)

    up8   = Conv2D(128, 2, activation=actv, padding='same', kernel_initializer=kern_init)(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation=actv, padding='same', kernel_initializer=kern_init)(merge8)
    conv8 = Conv2D(128, 3, activation=actv, padding='same', kernel_initializer=kern_init)(conv8)

    up9   = Conv2D(64,  2, activation=actv, padding='same', kernel_initializer=kern_init)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64,  3, activation=actv, padding='same', kernel_initializer=kern_init)(merge9)
    conv9 = Conv2D(64,  3, activation=actv, padding='same', kernel_initializer=kern_init)(conv9)
    conv9 = Conv2D(2,   3, activation=actv, padding='same', kernel_initializer=kern_init)(conv9)
    conv10 = Conv2D(1,  1, activation = 'sigmoid')(conv9)

    model = Model(input = inputs, output = conv10)

    model.compile(optimizer = Adam(lr = 1e-4), loss = 'binary_crossentropy', metrics = ['accuracy', iou])
    
    vgg_conv = VGG16(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

    for i in range(len(vgg_conv.layers)):
        weights = vgg_conv.layers[i].get_weights()
        layer = model.layers[i]
        layer.set_weights(weights)
        layer.trainable = False

    return model


def iou(y_true, y_pred):
    smooth=1e-5
    intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
    union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
    iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
    return iou


def trainGenerator(
    batch_size,
    image_path,
    mask_path,
    aug_dict,
    image_color_mode = "rgb",
    mask_color_mode = "grayscale",
    target_size = (256,256),
    seed = 1):
    '''
    can generate image and mask at the same time
    use the same seed for image_datagen and mask_datagen to ensure the transformation for image and mask is the same
    if you want to visualize the results of generator, set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(
        rescale=1./255,
        samplewise_center=True,
        samplewise_std_normalization=True,
        **aug_dict)
    mask_datagen = ImageDataGenerator(rescale=1./255, **aug_dict)
    image_generator = image_datagen.flow_from_directory(
        image_path,
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        interpolation='bilinear',
        seed = seed)
    mask_generator = mask_datagen.flow_from_directory(
        mask_path,
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        interpolation='bilinear',
        seed = seed)
    train_generator = zip(image_generator, mask_generator)
    for (img,mask) in train_generator:
        yield (img,mask)

# %%
target_size=(256,256)

data_gen_args = dict(
    rotation_range=0.3,
    width_shift_range=0.15,
    height_shift_range=0.15,
    #shear_range=0.05,
    zoom_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest')

batch_size=16

train_gen = trainGenerator(
    batch_size=batch_size,
    image_path=images_dir,
    mask_path=masks_path,
    aug_dict=data_gen_args,
    target_size=target_size)

val_gen = trainGenerator(
    batch_size=batch_size,
    image_path=os.path.join(root_dir, 'public_tests', '00_test_val_input', 'test', 'images'),
    mask_path=os.path.join(root_dir, 'public_tests', '00_test_val_gt'),
    aug_dict={},
    target_size=target_size)

from tensorflow.keras.models import load_model
model_path = os.path.join(model_dir, 'model10.hdf5')
model = unet(input_size=(None, None, 3), base=64)
#model = load_model(model_path, custom_objects={'iou': iou})
model_checkpoint = ModelCheckpoint(model_path, monitor='loss', verbose=1, save_best_only=True)
model.fit_generator(
    train_gen,
    steps_per_epoch=8382 // batch_size,
    #validation_data=val_gen,
    #validation_steps=20,
    epochs=30,
    callbacks=[model_checkpoint])
model.save(model_path)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:47: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
# Epoch 1/30
# Found 8382 images belonging to 200 classes.
# Found 8382 images belonging to 200 classes.
# 523/523 [==============================] - 333s 636ms/step - loss: 0.2557 - acc: 0.8442 - iou: 0.2371
#
# Epoch 00001: loss improved from inf to 0.25573, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 2/30
# 523/523 [==============================] - 326s 623ms/step - loss: 0.2027 - acc: 0.8748 - iou: 0.2947
#
# Epoch 00002: loss improved from 0.25573 to 0.20272, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 3/30
# 523/523 [==============================] - 327s 625ms/step - loss: 0.1865 - acc: 0.8840 - iou: 0.3208
#
# Epoch 00003: loss improved from 0.20272 to 0.18653, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 4/30
# 523/523 [==============================] - 328s 627ms/step - loss: 0.1741 - acc: 0.8895 - iou: 0.3435
#
# Epoch 00004: loss improved from 0.18653 to 0.17411, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 5/30
# 523/523 [==============================] - 327s 625ms/step - loss: 0.1659 - acc: 0.8934 - iou: 0.3605
#
# Epoch 00005: loss improved from 0.17411 to 0.16589, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 6/30
# 523/523 [==============================] - 326s 624ms/step - loss: 0.1572 - acc: 0.8967 - iou: 0.3783
#
# Epoch 00006: loss improved from 0.16589 to 0.15718, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 7/30
# 523/523 [==============================] - 326s 623ms/step - loss: 0.1498 - acc: 0.8999 - iou: 0.3947
#
# Epoch 00007: loss improved from 0.15718 to 0.14977, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 8/30
# 523/523 [==============================] - 326s 624ms/step - loss: 0.1445 - acc: 0.9019 - iou: 0.4078
#
# Epoch 00008: loss improved from 0.14977 to 0.14447, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 9/30
# 523/523 [==============================] - 326s 624ms/step - loss: 0.1397 - acc: 0.9033 - iou: 0.4220
#
# Epoch 00009: loss improved from 0.14447 to 0.13971, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 10/30
# 523/523 [==============================] - 326s 623ms/step - loss: 0.1351 - acc: 0.9044 - iou: 0.4350
#
# Epoch 00010: loss improved from 0.13971 to 0.13510, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 11/30
# 523/523 [==============================] - 326s 624ms/step - loss: 0.1304 - acc: 0.9061 - iou: 0.4468
#
# Epoch 00011: loss improved from 0.13510 to 0.13038, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 12/30
# 523/523 [==============================] - 327s 625ms/step - loss: 0.1268 - acc: 0.9069 - iou: 0.4575
#
# Epoch 00012: loss improved from 0.13038 to 0.12684, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 13/30
# 523/523 [==============================] - 327s 625ms/step - loss: 0.1236 - acc: 0.9075 - iou: 0.4688
#
# Epoch 00013: loss improved from 0.12684 to 0.12361, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 14/30
# 523/523 [==============================] - 327s 624ms/step - loss: 0.1204 - acc: 0.9084 - iou: 0.4787
#
# Epoch 00014: loss improved from 0.12361 to 0.12044, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 15/30
# 523/523 [==============================] - 326s 623ms/step - loss: 0.1162 - acc: 0.9095 - iou: 0.4911
#
# Epoch 00015: loss improved from 0.12044 to 0.11621, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 16/30
# 523/523 [==============================] - 327s 625ms/step - loss: 0.1132 - acc: 0.9102 - iou: 0.5003
#
# Epoch 00016: loss improved from 0.11621 to 0.11319, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 17/30
# 523/523 [==============================] - 326s 624ms/step - loss: 0.1102 - acc: 0.9108 - iou: 0.5110
#
# Epoch 00017: loss improved from 0.11319 to 0.11024, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 18/30
# 523/523 [==============================] - 326s 623ms/step - loss: 0.1086 - acc: 0.9109 - iou: 0.5185
#
# Epoch 00018: loss improved from 0.11024 to 0.10862, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 19/30
# 523/523 [==============================] - 325s 622ms/step - loss: 0.1044 - acc: 0.9120 - iou: 0.5310
#
# Epoch 00019: loss improved from 0.10862 to 0.10437, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 20/30
# 523/523 [==============================] - 329s 628ms/step - loss: 0.1035 - acc: 0.9120 - iou: 0.5384
#
# Epoch 00020: loss improved from 0.10437 to 0.10350, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 21/30
# 523/523 [==============================] - 327s 626ms/step - loss: 0.1021 - acc: 0.9119 - iou: 0.5439
#
# Epoch 00021: loss improved from 0.10350 to 0.10205, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 22/30
# 523/523 [==============================] - 327s 625ms/step - loss: 0.0988 - acc: 0.9127 - iou: 0.5555
#
# Epoch 00022: loss improved from 0.10205 to 0.09880, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 23/30
# 523/523 [==============================] - 326s 623ms/step - loss: 0.0967 - acc: 0.9129 - iou: 0.5641
#
# Epoch 00023: loss improved from 0.09880 to 0.09665, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 24/30
# 523/523 [==============================] - 326s 623ms/step - loss: 0.0942 - acc: 0.9137 - iou: 0.5726
#
# Epoch 00024: loss improved from 0.09665 to 0.09424, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 25/30
# 523/523 [==============================] - 326s 623ms/step - loss: 0.0936 - acc: 0.9135 - iou: 0.5783
#
# Epoch 00025: loss improved from 0.09424 to 0.09358, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 26/30
# 523/523 [==============================] - 325s 622ms/step - loss: 0.0904 - acc: 0.9143 - iou: 0.5870
#
# Epoch 00026: loss improved from 0.09358 to 0.09043, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 27/30
# 523/523 [==============================] - 325s 622ms/step - loss: 0.0901 - acc: 0.9143 - iou: 0.5922
#
# Epoch 00027: loss improved from 0.09043 to 0.09006, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 28/30
# 523/523 [==============================] - 326s 623ms/step - loss: 0.0871 - acc: 0.9147 - iou: 0.6020
#
# Epoch 00028: loss improved from 0.09006 to 0.08714, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 29/30
# 523/523 [==============================] - 326s 624ms/step - loss: 0.0867 - acc: 0.9147 - iou: 0.6059
#
# Epoch 00029: loss improved from 0.08714 to 0.08673, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5
# Epoch 30/30
# 523/523 [==============================] - 327s 625ms/step - loss: 0.0849 - acc: 0.9146 - iou: 0.6147
#
# Epoch 00030: loss improved from 0.08673 to 0.08489, saving model to /content/drive/My Drive/BirdsSegm/models/model10.hdf5

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy')
model.save(os.path.join(model_dir, 'model10_1.hdf5'))

# %%
model.fit_generator(
    train_gen,
    steps_per_epoch=8382 // batch_size,
    #validation_data=val_gen,
    #validation_steps=20,
    epochs=10,A
    callbacks=[model_checkpoint])

# %%
target_size=(256,256)

data_gen_args = dict(
    rotation_range=0.3,
    width_shift_range=0.15,
    height_shift_range=0.15,
    #shear_range=0.05,
    zoom_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest')

batch_size=16

train_gen = trainGenerator(
    batch_size=batch_size,
    image_path=images_dir,
    mask_path=masks_path,
    aug_dict=data_gen_args,
    target_size=target_size)

val_gen = trainGenerator(
    batch_size=batch_size,
    image_path=os.path.join('public_tests', 'public_tests', '00_test_val_input', 'test', 'images'),
    mask_path=os.path.join('public_tests', 'public_tests', '00_test_val_gt'),
    aug_dict={},
    target_size=target_size)

model_path = os.path.join(model_dir, 'model_vgg16.hdf5')
model = unet_vgg16(input_size=(None, None, 3))
#model = load_model(model_path, custom_objects={'iou': iou})
model_checkpoint = ModelCheckpoint(model_path, monitor='loss', verbose=1, save_best_only=True)
model.fit_generator(
    train_gen,
    steps_per_epoch=8382 // batch_size,
    #validation_data=val_gen,
    #validation_steps=40,
    epochs=40,
    callbacks=[model_checkpoint])
model.save(model_path)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:105: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Epoch 1/40
# Found 8382 images belonging to 200 classes.
# Found 8382 images belonging to 200 classes.
# 523/523 [==============================] - 330s 630ms/step - loss: 0.1606 - acc: 0.8973 - iou: 0.3676
#
# Epoch 00001: loss improved from inf to 0.16063, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 2/40
# 523/523 [==============================] - 320s 612ms/step - loss: 0.1366 - acc: 0.9107 - iou: 0.4059
#
# Epoch 00002: loss improved from 0.16063 to 0.13662, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 3/40
# 523/523 [==============================] - 325s 621ms/step - loss: 0.1309 - acc: 0.9123 - iou: 0.4208
#
# Epoch 00003: loss improved from 0.13662 to 0.13094, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 4/40
# 523/523 [==============================] - 325s 621ms/step - loss: 0.1255 - acc: 0.9134 - iou: 0.4353
#
# Epoch 00004: loss improved from 0.13094 to 0.12553, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 5/40
# 523/523 [==============================] - 323s 618ms/step - loss: 0.1233 - acc: 0.9134 - iou: 0.4450
#
# Epoch 00005: loss improved from 0.12553 to 0.12325, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 6/40
# 523/523 [==============================] - 324s 619ms/step - loss: 0.1173 - acc: 0.9148 - iou: 0.4596
#
# Epoch 00006: loss improved from 0.12325 to 0.11731, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 7/40
# 523/523 [==============================] - 323s 618ms/step - loss: 0.1140 - acc: 0.9155 - iou: 0.4706
#
# Epoch 00007: loss improved from 0.11731 to 0.11402, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 8/40
# 523/523 [==============================] - 324s 620ms/step - loss: 0.1112 - acc: 0.9158 - iou: 0.4800
#
# Epoch 00008: loss improved from 0.11402 to 0.11125, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 9/40
# 523/523 [==============================] - 324s 619ms/step - loss: 0.1099 - acc: 0.9154 - iou: 0.4886
#
# Epoch 00009: loss improved from 0.11125 to 0.10992, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 10/40
# 523/523 [==============================] - 324s 620ms/step - loss: 0.1068 - acc: 0.9160 - iou: 0.4991
#
# Epoch 00010: loss improved from 0.10992 to 0.10680, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 11/40
# 523/523 [==============================] - 325s 622ms/step - loss: 0.1039 - acc: 0.9163 - iou: 0.5092
#
# Epoch 00011: loss improved from 0.10680 to 0.10393, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 12/40
# 523/523 [==============================] - 324s 619ms/step - loss: 0.1016 - acc: 0.9165 - iou: 0.5185
#
# Epoch 00012: loss improved from 0.10393 to 0.10157, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 13/40
# 523/523 [==============================] - 324s 620ms/step - loss: 0.0977 - acc: 0.9173 - iou: 0.5317
#
# Epoch 00013: loss improved from 0.10157 to 0.09770, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 14/40
# 523/523 [==============================] - 324s 620ms/step - loss: 0.0951 - acc: 0.9174 - iou: 0.5411
#
# Epoch 00014: loss improved from 0.09770 to 0.09506, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 15/40
# 523/523 [==============================] - 325s 621ms/step - loss: 0.0961 - acc: 0.9166 - iou: 0.5437
#
# Epoch 00015: loss did not improve from 0.09506
# Epoch 16/40
# 523/523 [==============================] - 325s 622ms/step - loss: 0.0919 - acc: 0.9176 - iou: 0.5565
#
# Epoch 00016: loss improved from 0.09506 to 0.09195, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 17/40
# 523/523 [==============================] - 325s 621ms/step - loss: 0.0913 - acc: 0.9172 - iou: 0.5623
#
# Epoch 00017: loss improved from 0.09195 to 0.09126, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 18/40
# 523/523 [==============================] - 325s 621ms/step - loss: 0.0900 - acc: 0.9172 - iou: 0.5691
#
# Epoch 00018: loss improved from 0.09126 to 0.08996, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 19/40
# 523/523 [==============================] - 326s 623ms/step - loss: 0.0889 - acc: 0.9171 - iou: 0.5765
#
# Epoch 00019: loss improved from 0.08996 to 0.08888, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 20/40
# 523/523 [==============================] - 325s 621ms/step - loss: 0.0847 - acc: 0.9179 - iou: 0.5900
#
# Epoch 00020: loss improved from 0.08888 to 0.08471, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 21/40
# 523/523 [==============================] - 325s 621ms/step - loss: 0.0825 - acc: 0.9182 - iou: 0.5989
#
# Epoch 00021: loss improved from 0.08471 to 0.08247, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 22/40
# 523/523 [==============================] - 325s 621ms/step - loss: 0.0823 - acc: 0.9177 - iou: 0.6032
#
# Epoch 00022: loss improved from 0.08247 to 0.08231, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 23/40
# 523/523 [==============================] - 324s 620ms/step - loss: 0.0835 - acc: 0.9169 - iou: 0.6048
#
# Epoch 00023: loss did not improve from 0.08231
# Epoch 24/40
# 523/523 [==============================] - 325s 622ms/step - loss: 0.0797 - acc: 0.9179 - iou: 0.6161
#
# Epoch 00024: loss improved from 0.08231 to 0.07974, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 25/40
# 523/523 [==============================] - 325s 621ms/step - loss: 0.0773 - acc: 0.9183 - iou: 0.6264
#
# Epoch 00025: loss improved from 0.07974 to 0.07730, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 26/40
# 523/523 [==============================] - 324s 620ms/step - loss: 0.0766 - acc: 0.9182 - iou: 0.6304
#
# Epoch 00026: loss improved from 0.07730 to 0.07663, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 27/40
# 523/523 [==============================] - 325s 621ms/step - loss: 0.0756 - acc: 0.9183 - iou: 0.6364
#
# Epoch 00027: loss improved from 0.07663 to 0.07557, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 28/40
# 523/523 [==============================] - 324s 620ms/step - loss: 0.0727 - acc: 0.9187 - iou: 0.6475
#
# Epoch 00028: loss improved from 0.07557 to 0.07268, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 29/40
# 523/523 [==============================] - 323s 618ms/step - loss: 0.0737 - acc: 0.9182 - iou: 0.6484
#
# Epoch 00029: loss did not improve from 0.07268
# Epoch 30/40
# 523/523 [==============================] - 322s 615ms/step - loss: 0.0745 - acc: 0.9173 - iou: 0.6491
#
# Epoch 00030: loss did not improve from 0.07268
# Epoch 31/40
# 523/523 [==============================] - 322s 616ms/step - loss: 0.0719 - acc: 0.9183 - iou: 0.6590
#
# Epoch 00031: loss improved from 0.07268 to 0.07186, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 32/40
# 523/523 [==============================] - 324s 619ms/step - loss: 0.0703 - acc: 0.9182 - iou: 0.6657
#
# Epoch 00032: loss improved from 0.07186 to 0.07034, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 33/40
# 523/523 [==============================] - 323s 618ms/step - loss: 0.0678 - acc: 0.9187 - iou: 0.6751
#
# Epoch 00033: loss improved from 0.07034 to 0.06778, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 34/40
# 523/523 [==============================] - 324s 619ms/step - loss: 0.0665 - acc: 0.9189 - iou: 0.6812
#
# Epoch 00034: loss improved from 0.06778 to 0.06646, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 35/40
# 523/523 [==============================] - 324s 620ms/step - loss: 0.0666 - acc: 0.9185 - iou: 0.6840
#
# Epoch 00035: loss did not improve from 0.06646
# Epoch 36/40
# 523/523 [==============================] - 325s 621ms/step - loss: 0.0721 - acc: 0.9166 - iou: 0.6728
#
# Epoch 00036: loss did not improve from 0.06646
# Epoch 37/40
# 523/523 [==============================] - 324s 619ms/step - loss: 0.0651 - acc: 0.9188 - iou: 0.6920
#
# Epoch 00037: loss improved from 0.06646 to 0.06510, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 38/40
# 523/523 [==============================] - 316s 604ms/step - loss: 0.0646 - acc: 0.9189 - iou: 0.6963
#
# Epoch 00038: loss improved from 0.06510 to 0.06461, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 39/40
# 523/523 [==============================] - 314s 600ms/step - loss: 0.0636 - acc: 0.9187 - iou: 0.7010
#
# Epoch 00039: loss improved from 0.06461 to 0.06361, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16.hdf5
# Epoch 40/40
# 523/523 [==============================] - 313s 598ms/step - loss: 0.0645 - acc: 0.9184 - iou: 0.7005
#
# Epoch 00040: loss did not improve from 0.06361

# %%
target_size=(256,256)

data_gen_args = dict(
    rotation_range=0.3,
    width_shift_range=0.15,
    height_shift_range=0.15,
    #shear_range=0.05,
    zoom_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest')

batch_size=16

train_gen = trainGenerator(
    batch_size=batch_size,
    image_path=images_dir,
    mask_path=masks_path,
    aug_dict=data_gen_args,
    target_size=target_size)

model_path = os.path.join(model_dir, 'model_vgg16_1.hdf5')
model = load_model(os.path.join(model_dir, 'model_vgg16.hdf5'), custom_objects={'iou': iou})
model_checkpoint = ModelCheckpoint(model_path, monitor='loss', verbose=1, save_best_only=True)
model.compile(optimizer = Adam(lr = 4e-5), loss = 'binary_crossentropy', metrics = ['accuracy', iou])
model.fit_generator(
    train_gen,
    steps_per_epoch=8382 // batch_size,
    epochs=30,
    callbacks=[model_checkpoint])
model.save(model_path)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:350: UserWarning: Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
#   warnings.warn('Error in loading the saved optimizer '
# Epoch 1/30
# Found 8382 images belonging to 200 classes.
# Found 8382 images belonging to 200 classes.
# 523/523 [==============================] - 298s 569ms/step - loss: 0.0642 - acc: 0.9183 - iou: 0.7033
#
# Epoch 00001: loss improved from inf to 0.06417, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 2/30
# 523/523 [==============================] - 287s 549ms/step - loss: 0.0628 - acc: 0.9187 - iou: 0.7079
#
# Epoch 00002: loss improved from 0.06417 to 0.06280, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 3/30
# 523/523 [==============================] - 289s 552ms/step - loss: 0.0625 - acc: 0.9187 - iou: 0.7094
#
# Epoch 00003: loss improved from 0.06280 to 0.06254, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 4/30
# 523/523 [==============================] - 291s 557ms/step - loss: 0.0622 - acc: 0.9185 - iou: 0.7114
#
# Epoch 00004: loss improved from 0.06254 to 0.06217, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 5/30
# 523/523 [==============================] - 288s 550ms/step - loss: 0.0619 - acc: 0.9185 - iou: 0.7135
#
# Epoch 00005: loss improved from 0.06217 to 0.06186, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 6/30
# 523/523 [==============================] - 289s 553ms/step - loss: 0.0614 - acc: 0.9185 - iou: 0.7156
#
# Epoch 00006: loss improved from 0.06186 to 0.06139, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 7/30
# 523/523 [==============================] - 286s 546ms/step - loss: 0.0610 - acc: 0.9187 - iou: 0.7175
#
# Epoch 00007: loss improved from 0.06139 to 0.06099, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 8/30
# 523/523 [==============================] - 289s 552ms/step - loss: 0.0605 - acc: 0.9189 - iou: 0.7189
#
# Epoch 00008: loss improved from 0.06099 to 0.06051, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 9/30
# 523/523 [==============================] - 288s 550ms/step - loss: 0.0603 - acc: 0.9188 - iou: 0.7210
#
# Epoch 00009: loss improved from 0.06051 to 0.06026, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 10/30
# 523/523 [==============================] - 292s 559ms/step - loss: 0.0601 - acc: 0.9186 - iou: 0.7227
#
# Epoch 00010: loss improved from 0.06026 to 0.06009, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 11/30
# 523/523 [==============================] - 295s 564ms/step - loss: 0.0597 - acc: 0.9188 - iou: 0.7240
#
# Epoch 00011: loss improved from 0.06009 to 0.05966, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 12/30
# 523/523 [==============================] - 293s 561ms/step - loss: 0.0593 - acc: 0.9190 - iou: 0.7256
#
# Epoch 00012: loss improved from 0.05966 to 0.05929, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 13/30
# 523/523 [==============================] - 289s 553ms/step - loss: 0.0590 - acc: 0.9189 - iou: 0.7278
#
# Epoch 00013: loss improved from 0.05929 to 0.05904, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 14/30
# 523/523 [==============================] - 294s 562ms/step - loss: 0.0588 - acc: 0.9189 - iou: 0.7286
#
# Epoch 00014: loss improved from 0.05904 to 0.05876, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 15/30
# 523/523 [==============================] - 293s 560ms/step - loss: 0.0583 - acc: 0.9191 - iou: 0.7307
#
# Epoch 00015: loss improved from 0.05876 to 0.05835, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 16/30
# 523/523 [==============================] - 288s 551ms/step - loss: 0.0581 - acc: 0.9191 - iou: 0.7320
#
# Epoch 00016: loss improved from 0.05835 to 0.05812, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 17/30
# 523/523 [==============================] - 293s 560ms/step - loss: 0.0579 - acc: 0.9191 - iou: 0.7331
#
# Epoch 00017: loss improved from 0.05812 to 0.05789, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 18/30
# 523/523 [==============================] - 296s 566ms/step - loss: 0.0574 - acc: 0.9193 - iou: 0.7351
#
# Epoch 00018: loss improved from 0.05789 to 0.05744, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 19/30
# 523/523 [==============================] - 298s 570ms/step - loss: 0.0574 - acc: 0.9191 - iou: 0.7362
#
# Epoch 00019: loss did not improve from 0.05744
# Epoch 20/30
# 523/523 [==============================] - 290s 555ms/step - loss: 0.0572 - acc: 0.9190 - iou: 0.7381
#
# Epoch 00020: loss improved from 0.05744 to 0.05717, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 21/30
# 523/523 [==============================] - 287s 549ms/step - loss: 0.0571 - acc: 0.9189 - iou: 0.7385
#
# Epoch 00021: loss improved from 0.05717 to 0.05710, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 22/30
# 523/523 [==============================] - 293s 561ms/step - loss: 0.0567 - acc: 0.9189 - iou: 0.7401
#
# Epoch 00022: loss improved from 0.05710 to 0.05673, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 23/30
# 523/523 [==============================] - 294s 561ms/step - loss: 0.0566 - acc: 0.9189 - iou: 0.7419
#
# Epoch 00023: loss improved from 0.05673 to 0.05659, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 24/30
# 523/523 [==============================] - 291s 556ms/step - loss: 0.0563 - acc: 0.9190 - iou: 0.7423
#
# Epoch 00024: loss improved from 0.05659 to 0.05631, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 25/30
# 523/523 [==============================] - 291s 557ms/step - loss: 0.0561 - acc: 0.9190 - iou: 0.7442
#
# Epoch 00025: loss improved from 0.05631 to 0.05608, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 26/30
# 523/523 [==============================] - 287s 549ms/step - loss: 0.0557 - acc: 0.9191 - iou: 0.7449
#
# Epoch 00026: loss improved from 0.05608 to 0.05574, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 27/30
# 523/523 [==============================] - 294s 563ms/step - loss: 0.0555 - acc: 0.9193 - iou: 0.7466
#
# Epoch 00027: loss improved from 0.05574 to 0.05546, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 28/30
# 523/523 [==============================] - 292s 558ms/step - loss: 0.0553 - acc: 0.9191 - iou: 0.7476
#
# Epoch 00028: loss improved from 0.05546 to 0.05531, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 29/30
# 523/523 [==============================] - 289s 553ms/step - loss: 0.0550 - acc: 0.9192 - iou: 0.7486
#
# Epoch 00029: loss improved from 0.05531 to 0.05504, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_1.hdf5
# Epoch 30/30
# 523/523 [==============================] - 287s 549ms/step - loss: 0.0552 - acc: 0.9187 - iou: 0.7494
#
# Epoch 00030: loss did not improve from 0.05504

# %%
for layer in model.layers:
    layer.trainable = True
model.compile(optimizer = Adam(lr = 1e-5), loss = 'binary_crossentropy', metrics = ['accuracy', iou])
model_path = os.path.join(model_dir, 'model_vgg16_2.hdf5')
model_checkpoint = ModelCheckpoint(model_path, monitor='loss', verbose=1, save_best_only=True)
model.fit_generator(
    train_gen,
    steps_per_epoch=8382 // batch_size,
    epochs=40,
    callbacks=[model_checkpoint])
# Out:
# Epoch 1/40
# 523/523 [==============================] - 311s 595ms/step - loss: 0.0543 - acc: 0.9194 - iou: 0.7524
#
# Epoch 00001: loss improved from inf to 0.05427, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 2/40
# 523/523 [==============================] - 304s 582ms/step - loss: 0.0543 - acc: 0.9191 - iou: 0.7522
#
# Epoch 00002: loss did not improve from 0.05427
# Epoch 3/40
# 523/523 [==============================] - 304s 582ms/step - loss: 0.0541 - acc: 0.9191 - iou: 0.7530
#
# Epoch 00003: loss improved from 0.05427 to 0.05408, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 4/40
# 523/523 [==============================] - 317s 605ms/step - loss: 0.0539 - acc: 0.9191 - iou: 0.7534
#
# Epoch 00004: loss improved from 0.05408 to 0.05387, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 5/40
# 523/523 [==============================] - 320s 612ms/step - loss: 0.0539 - acc: 0.9190 - iou: 0.7543
#
# Epoch 00005: loss improved from 0.05387 to 0.05386, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 6/40
# 523/523 [==============================] - 320s 613ms/step - loss: 0.0539 - acc: 0.9189 - iou: 0.7535
#
# Epoch 00006: loss did not improve from 0.05386
# Epoch 7/40
# 523/523 [==============================] - 314s 600ms/step - loss: 0.0534 - acc: 0.9193 - iou: 0.7551
#
# Epoch 00007: loss improved from 0.05386 to 0.05338, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 8/40
# 523/523 [==============================] - 316s 604ms/step - loss: 0.0532 - acc: 0.9194 - iou: 0.7558
#
# Epoch 00008: loss improved from 0.05338 to 0.05319, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 9/40
# 523/523 [==============================] - 323s 617ms/step - loss: 0.0532 - acc: 0.9191 - iou: 0.7560
#
# Epoch 00009: loss did not improve from 0.05319
# Epoch 10/40
# 523/523 [==============================] - 321s 614ms/step - loss: 0.0530 - acc: 0.9193 - iou: 0.7562
#
# Epoch 00010: loss improved from 0.05319 to 0.05299, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 11/40
# 523/523 [==============================] - 329s 629ms/step - loss: 0.0532 - acc: 0.9191 - iou: 0.7556
#
# Epoch 00011: loss did not improve from 0.05299
# Epoch 12/40
# 523/523 [==============================] - 328s 627ms/step - loss: 0.0529 - acc: 0.9195 - iou: 0.7568
#
# Epoch 00012: loss improved from 0.05299 to 0.05291, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 13/40
# 523/523 [==============================] - 330s 631ms/step - loss: 0.0532 - acc: 0.9190 - iou: 0.7568
#
# Epoch 00013: loss did not improve from 0.05291
# Epoch 14/40
# 523/523 [==============================] - 330s 632ms/step - loss: 0.0529 - acc: 0.9193 - iou: 0.7572
#
# Epoch 00014: loss improved from 0.05291 to 0.05288, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 15/40
# 523/523 [==============================] - 330s 631ms/step - loss: 0.0531 - acc: 0.9188 - iou: 0.7571
#
# Epoch 00015: loss did not improve from 0.05288
# Epoch 16/40
# 523/523 [==============================] - 329s 630ms/step - loss: 0.0530 - acc: 0.9189 - iou: 0.7576
#
# Epoch 00016: loss did not improve from 0.05288
# Epoch 17/40
# 523/523 [==============================] - 328s 626ms/step - loss: 0.0527 - acc: 0.9192 - iou: 0.7584
#
# Epoch 00017: loss improved from 0.05288 to 0.05269, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 18/40
# 523/523 [==============================] - 322s 615ms/step - loss: 0.0526 - acc: 0.9192 - iou: 0.7588
#
# Epoch 00018: loss improved from 0.05269 to 0.05257, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 19/40
# 523/523 [==============================] - 318s 609ms/step - loss: 0.0525 - acc: 0.9192 - iou: 0.7588
#
# Epoch 00019: loss improved from 0.05257 to 0.05254, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 20/40
# 523/523 [==============================] - 321s 613ms/step - loss: 0.0526 - acc: 0.9188 - iou: 0.7591
#
# Epoch 00020: loss did not improve from 0.05254
# Epoch 21/40
# 523/523 [==============================] - 319s 610ms/step - loss: 0.0523 - acc: 0.9192 - iou: 0.7596
#
# Epoch 00021: loss improved from 0.05254 to 0.05230, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 22/40
# 523/523 [==============================] - 317s 607ms/step - loss: 0.0520 - acc: 0.9195 - iou: 0.7602
#
# Epoch 00022: loss improved from 0.05230 to 0.05201, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 23/40
# 523/523 [==============================] - 312s 596ms/step - loss: 0.0521 - acc: 0.9192 - iou: 0.7602
#
# Epoch 00023: loss did not improve from 0.05201
# Epoch 24/40
# 523/523 [==============================] - 310s 592ms/step - loss: 0.0522 - acc: 0.9189 - iou: 0.7607
#
# Epoch 00024: loss did not improve from 0.05201
# Epoch 25/40
# 523/523 [==============================] - 310s 593ms/step - loss: 0.0517 - acc: 0.9195 - iou: 0.7610
#
# Epoch 00025: loss improved from 0.05201 to 0.05175, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 26/40
# 523/523 [==============================] - 315s 602ms/step - loss: 0.0520 - acc: 0.9189 - iou: 0.7610
#
# Epoch 00026: loss did not improve from 0.05175
# Epoch 27/40
# 523/523 [==============================] - 315s 602ms/step - loss: 0.0515 - acc: 0.9196 - iou: 0.7621
#
# Epoch 00027: loss improved from 0.05175 to 0.05154, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 28/40
# 523/523 [==============================] - 314s 601ms/step - loss: 0.0519 - acc: 0.9189 - iou: 0.7618
#
# Epoch 00028: loss did not improve from 0.05154
# Epoch 29/40
# 523/523 [==============================] - 316s 605ms/step - loss: 0.0515 - acc: 0.9193 - iou: 0.7624
#
# Epoch 00029: loss improved from 0.05154 to 0.05151, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 30/40
# 523/523 [==============================] - 311s 595ms/step - loss: 0.0514 - acc: 0.9193 - iou: 0.7625
#
# Epoch 00030: loss improved from 0.05151 to 0.05144, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 31/40
# 523/523 [==============================] - 321s 613ms/step - loss: 0.0514 - acc: 0.9193 - iou: 0.7633
#
# Epoch 00031: loss improved from 0.05144 to 0.05139, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 32/40
# 523/523 [==============================] - 321s 613ms/step - loss: 0.0518 - acc: 0.9186 - iou: 0.7627
#
# Epoch 00032: loss did not improve from 0.05139
# Epoch 33/40
# 523/523 [==============================] - 323s 617ms/step - loss: 0.0512 - acc: 0.9193 - iou: 0.7633
#
# Epoch 00033: loss improved from 0.05139 to 0.05117, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 34/40
# 523/523 [==============================] - 320s 611ms/step - loss: 0.0512 - acc: 0.9193 - iou: 0.7645
#
# Epoch 00034: loss did not improve from 0.05117
# Epoch 35/40
# 523/523 [==============================] - 315s 603ms/step - loss: 0.0511 - acc: 0.9193 - iou: 0.7644
#
# Epoch 00035: loss improved from 0.05117 to 0.05106, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 36/40
# 523/523 [==============================] - 319s 609ms/step - loss: 0.0513 - acc: 0.9188 - iou: 0.7633
#
# Epoch 00036: loss did not improve from 0.05106
# Epoch 37/40
# 523/523 [==============================] - 312s 597ms/step - loss: 0.0508 - acc: 0.9196 - iou: 0.7654
#
# Epoch 00037: loss improved from 0.05106 to 0.05082, saving model to /content/drive/My Drive/BirdsSegm/models/model_vgg16_2.hdf5
# Epoch 38/40
# 523/523 [==============================] - 313s 599ms/step - loss: 0.0510 - acc: 0.9191 - iou: 0.7645
#
# Epoch 00038: loss did not improve from 0.05082
# Epoch 39/40
# 523/523 [==============================] - 317s 606ms/step - loss: 0.0509 - acc: 0.9191 - iou: 0.7659
#
# Epoch 00039: loss did not improve from 0.05082
# Epoch 40/40
# 523/523 [==============================] - 319s 610ms/step - loss: 0.0508 - acc: 0.9191 - iou: 0.7652
#
# Epoch 00040: loss did not improve from 0.05082
